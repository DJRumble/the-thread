# %%
#!pip install tqdm
#!pip install pyLDAvis
#! pip install boto3
#! pip install tensorflow
#! pip install "tensorflow_hub>=0.6.0"
#! pip install tensorflow==2.0.0
#!pip install stop_words

# %%
import numpy as np
import pandas as pd
import boto3

from sklearn.cluster import AgglomerativeClustering, SpectralClustering, KMeans, AffinityPropagation, MeanShift, DBSCAN, Birch

import tensorflow_hub as hub

import os

from sklearn import metrics

import re

import matplotlib.pyplot as plt

import collections
from collections import Counter
from stop_words import get_stop_words

# %%
#Itemise date and create a counter
def return_calander_wk(x,y,z):
    return datetime.date(x,y,z).isocalendar()[1]

def extend_weeks(x):
    if x < 10:
        x = '0{}'.format(x)
    else:
        x
    return '{}'.format(x)

def tokeniser(text):
    #  "nlp" Object is used to create documents with linguistic annotations.
    my_doc = nlp(text)

    # Create list of word tokens
    token_list = gensim.utils.simple_preprocess(text, deacc=True)

    return token_list

def remove_stop_words(token_list):
    # Create list of word tokens after removing stopwords
    filtered_text =[] 

    for word in token_list:
        lexeme = nlp.vocab[word]
        if lexeme.is_stop == False:
            filtered_text.append(word) 
            
    return filtered_text 

def stemmer(token_list):
    #Prepare stemming objects
    ps = PorterStemmer()
    
    stemm_list = []
    
    for j in token_list:
        stemm_list.append(ps.stem(j))
        
    return stemm_list

def is_name(word):
    #Prepare stemming objects

    common_names = ['damian','damo','stefan','paul','dave','david','phil','rob','jack','sam','sambo','james','hamish','verity','zac','holly']
    
    common_teams = ['unit','arsen','liverpool','spurs','brighton','west ham']
    
    name_flag = 0
    
    if word in common_teams:
        name_flag = 1
    if word in common_names:
        name_flag = 2
    
    return name_flag

def text_cleaning(x):
    return re.sub(r'[^A-Z a-z0-9]+', '', x).lower()


def clean_url(x):
    return re.sub(r'^https?:\/\/.*[\r\n]*', '', x, flags=re.MULTILINE)

# %% [markdown]
# ### Load the embedding model and vectorise the data
#
# There are two types of universal sentence encoder:
# 1. Universal sentence encoder, which is trained with a deep averaging network (DAN) encoder
# 2. Universal sentence encoder "large", which is trained with a Transformer encoder
#
# They both have different versions, 1. V1 to V4 and 2. V1 to V5.
# Main differences are that the early versions are trained with TensorFlow 1 and later versions are trained with TensorFlow 2.
#
# 1\. has the advantage that it can be used for transfer learning too; otherwise, I imagine performance to be similar.

# %%
# Define function to download the right model from S3 (the model can generally loaded from URL but on this AWS they have been blacklisted)
def downloadDirectoryFroms3(bucket,remoteDirectoryName):
    s3_resource = boto3.resource('s3')
    bucket = s3_resource.Bucket(bucket) 
    for object in bucket.objects.filter(Prefix = remoteDirectoryName):
        if not os.path.exists(os.path.dirname(object.key.split(project_folder)[-1])):
            os.makedirs(os.path.dirname(object.key.split(project_folder)[-1]))
        if object.key.split(project_folder)[-1][-1] != '/': #avoids trying to copy files from an empty folder
            bucket.download_file(object.key,object.key.split(project_folder)[-1])

# %%
bucket = 'bt-data-science-playground'

project_folder = 'nps-score-verbatim-text-analysis/'

model_filename = 'model_objects_UniversalSentenceEncoders/4' # look on S3 for available ones or download other versions from the Google's webpages

# Download the relevant model objects
downloadDirectoryFroms3(bucket, project_folder+model_filename)

embed = hub.load(model_filename)

# %%
#Load data from the full thread
df=pd.read_csv('data/PREP_combo_thread_data_20200516.csv')
df.head(3)

#Word Cloud specific prep
redacted_df = df.drop(df[df['text'] == ' MediaShared'].index)
redacted_df = redacted_df.drop(redacted_df[redacted_df['text'] == ' DeletedMsg'].index)
redacted_df = redacted_df.drop(redacted_df[redacted_df['text'] == ' Deleted Message'].index)

redacted_df.text = redacted_df.text.astype(str)

redacted_df['text'] = redacted_df['text'].apply(lambda x: clean_url(x))

# %%
# Get data as all the verbatim text in a single list
data = redacted_df['text'].values.tolist()

ids = redacted_df['text'].index

# %%
embeddings = embed(data)

print(embeddings.shape)
# Out:
# (52670, 512)

# %%
train = pd.DataFrame(np.array(embeddings))

# %%
from sklearn.metrics import silhouette_score

range_n_clusters = list (range(2,25))

for n_clusters in range_n_clusters:
    clusterer = KMeans(n_clusters=n_clusters)
    preds = clusterer.fit_predict(train)
    centers = clusterer.cluster_centers_

    score = silhouette_score(train, preds)
    print("For n_clusters = {}, silhouette score is {})".format(n_clusters, score))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-220-81f0f6d46c23> in <module>
#       8     centers = clusterer.cluster_centers_
#       9
# ---> 10     score = silhouette_score(train, preds)
#      11     print("For n_clusters = {}, silhouette score is {})".format(n_clusters, score))
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/metrics/cluster/_unsupervised.py in silhouette_score(X, labels, metric, sample_size, random_state, **kwds)
#     115         else:
#     116             X, labels = X[indices], labels[indices]
# --> 117     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#     118
#     119
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/metrics/cluster/_unsupervised.py in silhouette_samples(X, labels, metric, **kwds)
#     233                                     labels=labels, label_freqs=label_freqs)
#     234     results = zip(*pairwise_distances_chunked(X, reduce_func=reduce_func,
# --> 235                                               **kwds))
#     236     intra_clust_dists, inter_clust_dists = results
#     237     intra_clust_dists = np.concatenate(intra_clust_dists)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/metrics/pairwise.py in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    1611             X_chunk = X[sl]
#    1612         D_chunk = pairwise_distances(X_chunk, Y, metric=metric,
# -> 1613                                      n_jobs=n_jobs, **kwds)
#    1614         if ((X is Y or Y is None)
#    1615                 and PAIRWISE_DISTANCE_FUNCTIONS.get(metric, None)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/metrics/pairwise.py in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, **kwds)
#    1773         func = partial(distance.cdist, metric=metric, **kwds)
#    1774
# -> 1775     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1776
#    1777
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/metrics/pairwise.py in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1357
#    1358     if effective_n_jobs(n_jobs) == 1:
# -> 1359         return func(X, Y, **kwds)
#    1360
#    1361     # enforce a threading backend to prevent data communication overhead
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/metrics/pairwise.py in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     304         # To minimize precision issues with float32, we compute the distance
#     305         # matrix on chunks of X and Y upcast to float64
# --> 306         distances = _euclidean_distances_upcast(X, XX, Y, YY)
#     307     else:
#     308         # if dtype is already float64, no need to chunk and upcast
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/metrics/pairwise.py in _euclidean_distances_upcast(X, XX, Y, YY, batch_size)
#     496                     YY_chunk = YY[:, y_slice]
#     497
# --> 498                 d = -2 * safe_sparse_dot(X_chunk, Y_chunk.T, dense_output=True)
#     499                 d += XX_chunk
#     500                 d += YY_chunk
#
# KeyboardInterrupt:

# %%
#Use Clustering ALgorithm to Cluster Embeddings
n_topics_2 = 24
#n_samples=
labels_KM_final = KMeans(n_clusters = n_topics_2, random_state = 0).fit_predict(train)

# %%
#Create DataFrame with Data and Labels
columns = ['Topic', 'text']
output_samp = pd.DataFrame()
output_samp['Topic'] = labels_KM_final
output_samp['text'] = data

# %%
topic_count = Counter(output_samp['Topic'])

for i in range(0,(n_topics_2)):
    print({i}, topic_count[i])
# Out:
# {0} 1237
# {1} 1777
# {2} 2223
# {3} 2641
# {4} 1891
# {5} 4158
# {6} 1941
# {7} 365
# {8} 1444
# {9} 775
# {10} 1595
# {11} 1551
# {12} 2162
# {13} 746
# {14} 3167
# {15} 3121
# {16} 3773
# {17} 1438
# {18} 2190
# {19} 2293
# {20} 3719
# {21} 2312
# {22} 2894
# {23} 3257

# %%
for number in range(0,(n_topics_2)):
    data_numb = output_samp[output_samp['Topic'] == number]['text'].values
    np.set_printoptions(threshold=np.inf)
    
    stop_words = get_stop_words('en')
    newStopWords = ['service', 'wasnt', 'resolved', 'resolve', 'store', 'ee','phone', 'didnt', 'told', 'good', 'helpful', 
                   'get', 'will', 'sim', 'old', 'new', 'friendly', 'contract', 'deal', 'now', 'customer', 'im', 'app', 'went'
                    , 'sent', 'one', 'go', 'said', 'just', 'dont', 'got', 'still', 'ask', 'wanted','yeah','thats','like',
                   'lol','thats']
    stop_words.extend(newStopWords)
    df_frame = pd.DataFrame({ 'data_words': [str(data_numb)]})
    df_frame['data_words'] = df_frame['data_words'].str.replace("[^\w\s]", "").str.lower()
    df_frame['data_words'] = df_frame['data_words'].apply(lambda x: ' '.join([item for item in x.split() if item not in stop_words]))
    most_common_ = df_frame['data_words'].str.split(expand=True).stack().value_counts() 
    print('\n', most_common_[0:10])
# Out:
#  brexit      181
# vote        170
# labour      131
# tories       83
# election     75
# tory         75
# lib          73
# people       72
# think        69
# trump        67
# dtype: int64
#
#  ah         68
# know       59
# think      59
# see        49
# thought    40
# ive        39
# well       37
# cant       36
# need       26
# though     26
# dtype: int64
#
#  shit        323
# fucking     218
# fuck        209
# cunt         72
# troll        48
# butthurt     47
# cant         45
# trolling     43
# fucked       42
# really       40
# dtype: int64
#
#  football    274
# league      222
# team        211
# game        209
# cup         167
# win         163
# season      147
# world       133
# players     128
# can         114
# dtype: int64
#
#  next      18
# fake      17
# news      17
# also      17
# true      15
# 2         13
# 10        11
# think     10
# back      10
# thanks    10
# dtype: int64
#
#  back      66
# big       66
# news      65
# time      55
# people    52
# great     52
# bbc       49
# can       47
# first     47
# also      46
# dtype: int64
#
#  eat       98
# food      91
# meat      71
# can       67
# eating    65
# bread     61
# shit      52
# cheese    52
# also      46
# ive       45
# dtype: int64
#
#  7      55
# 3       7
# 9       1
# 5       1
# 6       1
# ___     1
# l       1
# dtype: int64
#
#  nan    1444
# dtype: int64
#
#  ah       106
# haha      45
# oh        34
# fuck      30
# kek       18
# shit      17
# lel       13
# ha        12
# sorry     10
# wut       10
# dtype: int64
#
#  whats     193
# much       60
# can        52
# whos       49
# even       42
# know       41
# going      40
# many       36
# people     31
# fuck       29
# dtype: int64
#
#  hes         396
# think        57
# though       49
# can          47
# well         43
# guy          37
# shit         37
# also         34
# probably     33
# really       31
# dtype: int64
#
#  youre    168
# can      116
# youve     99
# damo      75
# need      65
# jack      55
# youd      51
# want      50
# rob       49
# see       45
# dtype: int64
#
#  yes          81
# nah          65
# yep          38
# yeh          28
# ah           27
# oh           17
# obviously    16
# exactly      13
# sure         11
# nope          9
# dtype: int64
#
#  dave        340
# sam         261
# paul        192
# phil        191
# rob         185
# jack        141
# damian      112
# can          96
# stefan       94
# nickname     78
# dtype: int64
#
#  honk       72
# ball       38
# big        33
# goat       32
# little     28
# hoot       26
# full       23
# honking    20
# shit       19
# mad        18
# dtype: int64
#
#  arsenal      207
# liverpool    183
# united       149
# league       140
# back         139
# chelsea      125
# hes          123
# goal         120
# think        117
# season       113
# dtype: int64
#
#  great        129
# big           58
# nice          49
# excellent     43
# classic       43
# dat           35
# huge          31
# sounds        30
# game          27
# cheers        27
# dtype: int64
#
#  jack      27
# paul      20
# sam       19
# rob       17
# kane      16
# boy       16
# dave      16
# big       15
# mr        15
# damian    14
# dtype: int64
#
#  hib                                                                                                                                                                                                                                                                                                                                                                          99
# hebib                                                                                                                                                                                                                                                                                                                                                                        25
# 7                                                                                                                                                                                                                                                                                                                                                                            18
#     17
# sweepy                                                                                                                                                                                                                                                                                                                                                                       10
# u200d                                                                                                                                                                                                                                                                                                                                                                        10
# dyor                                                                                                                                                                                                                                                                                                                                                                          9
# london                                                                                                                                                                                                                                                                                                                                                                        8
# ffaf                                                                                                                                                                                                                                                                                                                                                                          6
# fairps                                                                                                                                                                                                                                                                                                                                                                        6
# dtype: int64
#
#  people    307
# can       275
# shit      242
# think     209
# time      200
# going     159
# also      150
# really    136
# back      133
# cant      131
# dtype: int64
#
#  can        250
# going      225
# weekend    184
# ill        184
# back       165
# week       160
# work       145
# friday     139
# time       129
# wales      126
# dtype: int64
#
#  though    70
# well      59
# can       44
# also      43
# never     40
# cant      38
# need      37
# going     33
# back      31
# even      28
# dtype: int64
#
#  can         242
# need        161
# though      150
# well        144
# think       121
# probably    117
# going       112
# cant         87
# might        77
# shit         73
# dtype: int64

# %%
output_samp.loc[output_samp['Topic'] == 0].head(50)
# Out:
#      Topic                                               text
# 0        0                                          hebiiiiib
# 1        0                                              hibeb
# 13       0                                       +12813868870
# 20       0                                          facebexit
# 31       0                                              damo?
# 36       0                                                 👍🏿
# 37       0                                                🐄👈🏻
# 39       0                                                  🍆
# 40       0                                               🤷🏻‍♀
# 42       0                                                  💩
# 50       0                                            >poetry
# 59       0                                                 👌🏻
# 72       0                                              colby
# 75       0                                       >beef hearts
# 85       0                                               7/10
# 108      0                                                 👍🏿
# 110      0                                   >arsehole wagner
# 131      0   https://www.economist.com/news/science-and-te...
# 144      0                                            stephen
# 147      0       https://en.m.wikipedia.org/wiki/mars_program
# 156      0                                               hero
# 158      0                       https://youtu.be/9_rtokgpnx4
# 170      0                                                 👍🏿
# 176      0                                                 🍒🍌
# 225      0   https://twitter.com/brfootball/status/9793133...
# 234      0                                               hink
# 235      0                                              hebib
# 237      0   https://www.mirror.co.uk/news/uk-news/shocked...
# 239      0   https://www.facebook.com/officialdugout/video...
# 252      0                                         devvvidddd
# 260      0                                           puckered
# 261      0                                            chapped
# 282      0                                       would cause*
# 292      0                                       brain-rumble
# 295      0                                       >this person
# 303      0                                          brimming.
# 322      0                                             crufts
# 323      0                                         unmissable
# 324      0                                               hoot
# 328      0                                              to wi
# 330      0                                              bunce
# 339      0   https://twitter.com/nickvann1987/status/98267...
# 345      0                                               foxy
# 347      0                                >chorlton-cum-hardy
# 350      0                                          cum-hardy
# 371      0                                         pep’s face
# 379      0   https://www.economist.com/news/middle-east-an...
# 384      0                                          lib derps
# 389      0                                          >coutinho
# 391      0                                              >life

# %%
#Create Dataset for each cluster
data = output_samp['text'].values
data_0 = output_samp[output_samp['Topic'] == 0]['text'].values # > topic and URLs
data_1 = output_samp[output_samp['Topic'] == 1]['text'].values # large General conversation
data_2 = output_samp[output_samp['Topic'] == 2]['text'].values # NAN
data_3 = output_samp[output_samp['Topic'] == 3]['text'].values # Football
data_4 = output_samp[output_samp['Topic'] == 4]['text'].values # Short conversation
data_5 = output_samp[output_samp['Topic'] == 5]['text'].values # < 3 word response
np.set_printoptions(threshold=np.inf)

# %%
data_5
# Out:
# array([' only', ' what is this', ' please explain', ' lol', ' perfect',
#        ' i think it is', ' whatever', ' 👍', ' it’s a good one', ' lol',
#        ' haha', ' ah. so good', ' lol', ' oh no', ' ?', ' anyone?',
#        ' lol amazing', ' *is', ' hahahaha', ' nah i’m in loondon',
#        ' there is', ' 👌', ' haha yeah', ' tonight', ' it begins',
#        ' bollocks', ' o rly', ' 👍', ' fair', ' not necessarily..',
#        ' he’s', ' 👍', ' i have it currently', ' this is mine', ' correct',
#        ' only just', ' hard to say', ' would like that', ' very deep',
#        ' lol', ' so hard', ' perfect', ' lol out loud', ' or maybe:',
#        ' ___', ' nah from leamington', " not that i'm aware of",
#        ' yeah it has.', " that's encouraging", ' as in right now?', ' 👍',
#        ' what?', ' yes', ' ah so it begins', ' yeah', ' nice.', ' lol',
#        ' just scored', ' ah - 1-1', ' ?', ' i was thinking first',
#        ' fucking two', ' i ❤ acid', ' kek', ' nah...', ' not for me',
#        ' honest mate', ' lol', ' just catheterise me',
#        ' something like that', ' ?', ' yeah', ' yeah', ' yeah actually',
#        ' no one', ' ah yeah - pricks', ' lol', ' lol', ' rekt', ' lol',
#        ' actually', ' ah. vital', ' yeah that makes sense', ' why?',
#        ' lol', ' yeah yeah yeah', ' here we go', ' ...it is', ' no',
#        ' many times', ' wuts there', ' anyway', ' lol', " can't do it.",
#        ' lol', ' i am', ' very indeed', " yes i'm on it", ' all night?',
#        ' not really', ' yeah i agree', " it's pretty good", ' hmmm',
#        ' lol', ' yeah no worries', ' i am?', ' yeah yeah', ' very droll',
#        ' 10?', ' dick', ' in', ' son', ' “sorry i fell”', ' 👍', ' lol.',
#        ' mostly 40+', ' *make it', ' that’s crufts', ' so good',
#        ' so good', ' going in', ' *made him', ' lol', ' what the fuck',
#        ' nice', ' no joke', ' ok will do', ' it worked',
#        ' yeah yeah yeah', ' lol', ' sure', ' 👍', ' yeah', ' :-(',
#        ' been there done that', ' obviously.', ' quite strong', ' yeah',
#        ' fair', ' lol no idea', ' good lad', ' lol',
#        ' done it already...', ' lol. to both.', ' lol', ' good',
#        ' in* ffs', ' excellent', ' so wrong', ' highly debatable',
#        ' not that one!', ' of course.', ' nah', ' not that bad',
#        ' no shit', ' fact', " yeah i'll do one", ' lol', ' lol', ' yeah',
#        ' yep', ' 2 please', " now we're talking...", ' kek',
#        ' is it though...', ' lol', ' no idea', ' nice and specific', ' 👍',
#        ' nice one.', ' oh god', ' 👍', ' *meant to be', ' makes sense',
#        ' off reddit', ' 👍', ' ah', ' oh i see', ' obviously', ' always',
#        ' elaborate', ' yeah early', ' pretty much', ' not good enough',
#        ' no no no', " that's the one", ' yeah yeah', ' i know',
#        ' what is this', " that'd be fucking great", ' woops',
#        ' yeah yeah yeah', ' ah good', ' lol.', ' rekt', ' yeah yeah yeah',
#        ' nah', ' yeah', " don't think so", " ah that's ideal", ' yeah',
#        ' yeah', ' lol', ' yeah', ' lol', ' u mad', ' lol', ' 👍', ' lol',
#        ' just in general?', ' haha', ' must be decent',
#        ' that seems great', " that's pretty crucial", ' nah thinknso',
#        ' yeh', " he's my man", ' ah yeah', " i'm sold", ' *first',
#        ' yeah this is great', ' this is too good', " it's been great",
#        ' yeah yeah yeah', ' yeh yehyeh', ' lol.', ' 👍', ' obviously ...',
#        ' been saying this', ' ah', ' ah maybe', ' stupid', ' fuck sake',
#        ' yeah. idiotic', ' just saying', ' yeah', ' finally', ' lol',
#        ' my dick!', ' he is', ' sad', ' ah', ' but also', ' *say',
#        ' yeah yeah yeah', ' nah mate', ' yeah', ' no no', ' fuck',
#        ' ah. weeel', ' easy', ' shit storm', ' lol',
#        ' that was the moment', ' just read that...', ' you need that',
#        ' book it', ' that is so shit', " 'cool'", ' holy fuck',
#        ' yeah yeah', ' ah', ' yeah', ' right decision',
#        ' yeah great decision', ' fuck', ' yeah', ' yeah', ' ah', ' 👍',
#        ' ok', ' finally', ' than*', ' kek', " yeah it's great.", ' go 4',
#        ' thanks', ' i disagree', ' lel', ' ah', ' shit', ' nahhh',
#        ' in other news...', ' 👍', ' 👍', ' fuck', ' fuck', ' fuck me',
#        ' yeh yeh yeh', ' that was great', ' just saw it',
#        ' what is this?', ' lol', ' this is insane', ' true', ' lol',
#        ' ah', ' fuck sake.', ' yeah', ' lol', ' we probably could',
#        ' nah', ' please', ' yeah me too', ' well 10/3', ' .', ' yes',
#        ' ah fuck', ' yes silly question', ' probs samira actually', ' ho',
#        " i'm sorry what?", ' true.', ' this.', ' yeah. predictable',
#        ' yeah', ' yaaaas', ' ah great', ' lel', ' 👍', ' good point',
#        ' yeah', " *wasn't", ' lol. balmy', ' just in time', ' lol',
#        ' yeah >brazil', " ah. maybe that's why", ' truth', ' this. game.',
#        ' huge', ' *this', ' yeah', ' ah yeah', ' yeah that would be good',
#        ' this is too much', ' that save', ' true', ' not that far',
#        ' yeah yeah yeah', ' no', ' yeah', ' huge', ' ah. hebib', ' ah',
#        ' unbelievable', ' very nice', ' ah fuck it', ' good point',
#        ' just discussed.', ' fuck', ' fuck', ' fuck', ' come', ' on',
#        ' oh great', ' thank god for that', ' fuuuuuck', ' 👍', ' simple',
#        ' why not', ' not sure', ' no need', ' well i was wrong then',
#        ' whoops', ' terrible', ' defo', ' may as well', ' back on!', ' 👍',
#        ' yes', ' que?', ' ummmm... yes', ' that would work right?', ' 👍',
#        ' *apparently', ' true.', ' gr8 b8 m8', ' no', ' yeah true',
#        " you're*", ' not yet', ' very intense', ' yep got it',
#        ' excuse me', ' ah rass', ' nothing.', ' bollocks', ' lol',
#        ' lol that guy', ' much.', ' fuck', ' boring m8', ' ah.', ' 👍',
#        ' what', ' jarmalenko m8', ' fake', ' 👍', ' just saying', ' ...',
#        ' great timing', ' yes', ' got that too', ' seconded', ' *?',
#        ' yeah classic', ' i like that', ' yeah', ' *any',
#        ' yeah got to. i', ' 9 ish', ' good good', ' cheers mate', ' yep',
#        ' yeah yeah', ' yes', ' 👍', ' maybe 5', ' literally me...',
#        ' sorry / not sorry', ' sounds reasonable', ' nah.', ' nah',
#        ' makes sense', ' classic', ' i reckon so', ' looks great',
#        ' looking good', ' it actually doea', ' it begins', ' yep',
#        ' this', ' cool cheers', ' cheers boi', ' gonna get on it',
#        ' *first', ' yes', ' bit like this?', ' yeah', ' so lovely.',
#        ' fuckin lovely', ' let’s see', ' ah', ' sounds excellent',
#        ' classic', ' surely wikishart?', ' 👍', ' thank you',
#        " i'm around", ' yeah', ' yeh i can do either', ' yeah',
#        ' very cute.', ' cute', ' lol diogo dalot', " yeh i've seen this",
#        ' not sure about that', ' yeah', ' not happening', ' i’m in',
#        ' nah nah 7', ' yes', ' yes', ' 👍', ' yeah', ' fuck sake',
#        " trollin'", ' yep', ' lol', ' oh fuck 1min', ' jesus',
#        ' so nervous', ' yeh', ' lol', ' oh', ' man', ' shit',
#        ' yes i reckon', ' yes', ' nice', ' >not all', ' so good.',
#        ' this is great', ' how much?', ' lol', ' yeah. do it',
#        ' ah. pete.', ' lol this as well', ' yeah yeah yeah', ' also love',
#        ' *from it', ' *and', ' yes', ' sorry 11th', ' lame', ' lol',
#        ' ah ah that got me', ' shit #7', ' yeah yeah yeah',
#        ' very trolly', ' got to this:', " i'd have to agree",
#        ' obviously shevshenko', " i've been thinking this", ' 👍', ' lol',
#        " i'm going", ' yeah keen for it', ' yeah it does', ' 👍', ' kek',
#        ' watch this', ' i did', ' had to happen', ' oh dear',
#        ' been before', ' 👍', ' so chantable..', ' this game',
#        ' very birthdroll', ' so birthday', ' much happy', ' wats',
#        ' cool', ' cool', ' ah.', ' damn', " i'm loving it",
#        ' yeah yeah yeah', ' i did that', ' ah', ' damn',
#        ' well that was lovely', ' nice', ' yep', ' sounds good', ' lol',
#        ' lol', ' lol. no', ' lol', ' this game', ' ah. ah. ah. yeah.',
#        ' yeah', ' rekt', ' ah', ' is it on now?', ' ???', ' better',
#        ' yeah thanks mate', ' so naughty', ' definitely a good way',
#        " that's set it up nicely", ' rubbish', ' fuck sake',
#        ' fair enough', ' yeah', ' (y)', ' still got it', ' why not?',
#        ' obviously', ' yeah', ' lol', ' haha', ' wait what?', ' 👍',
#        ' nah', ' no', ' nah', ' *the man', ' that run up',
#        ' great finish', ' fake', ' this is great', ' 1-1',
#        ' yeah yeah yeah', ' loving it', ' just saying', ' yeah yeah',
#        ' that guy', ' already its great', ' had it', ' done.', ' love it',
#        ' fuck that', ' so grotty', ' very puntastic', " well i'm in",
#        ' are q joking mate?', ' 👌', ' lol', ' link please', ' lol',
#        ' lol', ' nah. nah', ' yep', ' fair', ' lol', ' wut?',
#        ' it was great', ' yep', ' always', ' great joke', ' lol', ' also',
#        ' lol that’s so good', ' *as in', ' kind of', ' exactly', ' wot?',
#        ' yeah.', " yeah it's great", ' no doubt', ' why?', ' 👍',
#        ' the original', ' though*', ' lol', ' have them', ' up*', ' ok',
#        ' ah yeah', " that's a lot", ' like q', ' no', ' lel 2',
#        " that's very shit", ' 👍', ' shit', ' kek', ' lovely home', ' lol',
#        ' and now this', ' nope', ' what is it?', ' ah it is that',
#        ' that it is', ' yeah', ' no way', " yeah we'll be there.",
#        ' yeah that would help', ' beautiful', ' total shit', ' lol',
#        " that's huge", ' finally', ' genius', ' 👍', " it's happening",
#        ' kek', ' yep', " and that's a mate", ' yeah who knew', ' 👍', ' 👌',
#        ' shit', ' nah', ' ah that explains it', ' "that\'s fucked"',
#        ' lol', " that'll be great", ' particularly grotty', ' 👍',
#        ' it begins', ' damo lol', ' no shit', ' lmao',
#        ' very anti-snacking', ' ah...', ' fucking hell', ' lol',
#        ' classic', ' yeah', ' yeah yeah', ' ah no', " he didn't?",
#        ' oh yeah?', ' ah', ' lol', ' lol indeed', ' unbelievable',
#        ' i tried', ' i have it', ' fuck*', ' yeah me too', ' yeah',
#        " that's massive", ' 👍', ' yeah', ' look', ' yeah', ' yeah yeah',
#        ' yeah yeah', ' nah', ' i got nothing', ' 👍', ' yeah yeah',
#        ' nope', ' yeah either', ' this is great', ' lol', ' lol',
#        ' *this herself', ' oh i see', " it's hilarious", ' 👍',
#        ' this game', ' not yet', ' you have to', ' lol',
#        ' lol already great', ' ha', ' yeah yeah', ' makes sense',
#        ' no worries', ' would be good', ' *am', ' yeah 1am sounds good',
#        ' as well', ' very close', ' 👍', ' n o t i c e', ' thanks',
#        ' so very shit', ' *saying that', ' loved it.', ' excellent',
#        ' yeah surely', ' nah', ' lol', " that's a nut", ' no',
#        ' ah right.', ' *like', ' lol', ' what happens?', ' wut?',
#        ' unbelievable', ' 👍', ' great', ' but q though', ' lol', ' lol',
#        ' this is brilliant', ' deal with it', ' i suppose', ' this',
#        ' easy', ' *me*', ' yep', ' not sure where', ' not one of us?',
#        ' almost', ' that’s something we’d do', ' lol sarri out', ' lol',
#        ' ?', ' lol that guy', ' same', ' aha.', ' not true', ' no', ' no',
#        ' yes', ' lol', ' bit of everything', ' no', ' precisely',
#        ' just fyi.', ' ah yeah lol', ' kek', ' yep', ' he is good',
#        ' sweet?', ' yeet', ' ah yes', ' ?', ' did this happen?',
#        ' ages ago', ' such quality', ' fuck that', ' i don’t care',
#        ' that seems fair', ' just now', " there's some context...",
#        ' yeah', ' so there', ' fair play', ' agreed', ' please no',
#        ' thanks', ' wut?', ' lol', ' it’s great', ' ah no lol', ' lol',
#        ' perfect', ' so good', ' yeah yeah', ' yeah lol', ' but good',
#        " haven't seen that", ' lol', ' why _still_?', ' nah', ' not true',
#        ' fact', ' nah', ' yes', ' yeah yeah', ' *mr', ' pretty much',
#        ' lol', ' even better', ' yeah vital', ' lol', ' not the same',
#        ' 👌', ' fuck you', ' lol', ' lol', " that's good", ' just read it',
#        " you'll have...", ' lol', ' yeah', ' that was great',
#        " that's it yeah", ' love it', " no it's not", ' *top*',
#        ' perfectly fine.', " it's really good", ' nothing', ' yes',
#        ' yeah probably', ' lol', ' lol', ' lol', ' ah good', ' lol',
#        " i didn't want to know", " yeah it's great", ' classic', ' lol',
#        " that's it", ' lol', ' nope?', ' lol', ' yep it’s on', ' 👍', ' ?',
#        ' classic', ' haha', ' 👍', " yeah - 'i'm just trolling'",
#        " he's got him", ' i like it', ' lol', ' explain?', ' no idea',
#        ' even better', ' 👍', ' lol. rekt.', ' amazing', ' i get that too',
#        ' nope?', ' very close', ' lol', ' 👍', ' about 5 minutes ago',
#        ' lol.', ' ha', ' lovely jubbly', " 'hi gene'",
#        ' ha. yeah. rate that', ' google mate', " that's mental", ' 👍',
#        ' nah', ' 2 of', ' lol', ' cool', ' lol', ' "yeah sure"',
#        ' it knew', " i'd take it", ' no', ' yeah yeah', ' bollocks',
#        ' oops mistell', ' ah yeah', ' 👍', ' lol', ' yeah y not',
#        ' you ok hun?', ' yeah that looks great', ' you don’t know',
#        ' says it all', ' unbelievable', ' ever heard of it', ' what?',
#        ' lol britbox', ' but britbox mate', ' no chance', ' not live',
#        ' absolutely', ' it was okay', ' thanks guys', ' wut?',
#        ' yeah that was ridiculous', ' a', ' r', ' lol peno', ' lol', ' 👍',
#        ' ah', ' yeah', ' lol', ' lol', ' good for me', ' all 20?',
#        ' a good amount of them', ' ha amazing', ' lol', ' lol', ' *were',
#        ' yeah exactly', ' yeah defo', ' perfect',
#        ' ooof. i’m gurning over that', ' always.', ' no', ' i say',
#        ' explain?', ' ah.', " that's ideal", ' good night',
#        ' not so much.', ' yeah same', ' yeah', ' of its time',
#        ' fuck off', ' easy', ' very spursy', ' nah nah nah',
#        " it's great", ' turned it off', " it's shit.", ' precisely.',
#        ' does it?', ' very 2003', ' haha', ' yeah link us', ' ooooooo',
#        ' this*', ' that will be great', ' yeah', ' shite', ' huge',
#        ' what?', ' yeah', ' sorry', " i'm not going", ' fuck this.',
#        " i'm out", ' yeah yeah', ' 👌', ' 👍', ' not interested', ' 👍',
#        ' far from certain', ' wot???', ' but*', " i'm sarri?", ' truth',
#        ' didn’t actually happen', ' shit news', ' ah ok', ' very nice',
#        ' now it’s 3', ' at work', ' complete shit',
#        ' yeah good luck with that.', ' nice', ' of bollocks',
#        ' excellent', ' 25 sorry', ' yeah yeah', ' lol',
#        ' fucking brilliant', ' oh yeah?', ' or just that?', ' just that',
#        ' impressive', ' lol that’s great', ' haha brilliant',
#        ' no context', ' *is massively', ' nope', " yeah that's fair",
#        ' agreed', ' lol not a thing', ' yeah yeah', ' but undroppable',
#        ' so good.', ' this happened', ' ha yes exactly that', ' lol',
#        ' lol', ' as an aside', ' kek', ' great', " didn't even know",
#        ' fucking wonderful', ' nah', ' go on', ' "what?"', ' no',
#        ' question', ' ❤', ' so broken', ' 👍', ' yeah yeah', ' ah yeah',
#        " 'fun fact'", ' at all points', ' lol', ' lol', ' very true',
#        ' she', ' lol', ' cheers though', " yeah that's excellent",
#        ' why me?', ' you’re yentob', ' so quick.', ' lol', ' *shit',
#        " 'sorry m8'", ' 👍', ' yeah', ' yeah it was', ' yeah yeah',
#        " yeah that's awful", ' exactly', ' yeah', ' ha', ' 👍',
#        " there's your answer", ' very close that.',
#        " don't see the issue", ' ah. well.', ' good point',
#        " i think we're doing a bit of that", ' sorry?', ' nah just suck',
#        " i'll back this", ' works', ' no', ' disgusting', ' no',
#        ' agreed', ' nearby', ' lel', ' that would be good', ' yeah yeah',
#        ' lol', ' yeah yeah', ' so it begins', ' so excited',
#        ' notre damn', ' better be.', ' why', ' fuck', ' ahem', ' ah',
#        ' same', ' yeah not sure i get this', ' lol', ' no.', ' boring',
#        ' this is great', ' lol', ' 👍', ' 👍', ' it is rather decent',
#        ' lol', ' ah yeah', ' ??', ' fair', ' yaaas', ' yeah same',
#        ' guilty as well', ' ah.', " 'oh julian'", ' total shit', ' errr',
#        ' ah', ' i did the same', ' i am ded', ' no thankyou',
#        ' very close', ' lol', ' that really is excellent', ' great',
#        ' so lucky', ' wtf', ' ah. well', ' lol', ' nice timing', ' lol',
#        ' sure there are p', " you'd take that", ' nah don’t think so',
#        " yeah that's him", ' fair enough', ' finally', ' most probably',
#        ' holy shit', " i'm beyond that", ' 👍', " i'm gone.", ' no',
#        ' lol', ' 👍', ' fuck off', ' fuck sake', ' this game', ' nah',
#        ' lol', ' yeah yeah', ' sweet', ' 👍', ' 👍', ' lol damo', ' yeah',
#        ' yeah yeah', ' no', ' ah', ' i know... ridiculous', ' its great.',
#        ' huge', ' lol', ' yeah brutal', ' only 6', ' yeah', ' lol yeah',
#        ' 👍', ' all wrong', ' is this you?', ' yep', ' 👍', ' yeah yeah',
#        ' better', ' i was aware', ' good point', ' no', ' 👍', ' lol',
#        ' yeah', ' that was it', ' highly', ' lol', ' loron moron', ' 👍',
#        ' good pace', ' yep', ' yeah', ' yeah', ' yeah', ' worked',
#        ' so good', ' that would be hillarious', ' lolllll', ' 👍',
#        ' i think:', ' yes.', ' ??', ' lol no', ' *he', ' shame',
#        ' i think he did', ' but jaaaack.', ' yeah yeah', ' woof',
#        ' winner', " i'm sorry?", ' 👍', ' lol. no.', ' haha', ' ??',
#        ' nah', ' ?', ' lol', ' lol so grotty', ' nah never', ' ah',
#        ' oh fuck', ' wtf', ' yeah yeah', ' yeah', ' yeah its good',
#        ' yeah really good', ' ha', ' yeah yeah.', ' we did', ' lol',
#        ' this is good', ' nah', ' yeah yeah yeah.', ' lol', ' "no"',
#        ' "no"', ' but', ' "no"', ' 👍', ' interesting', ' i see', ' lol',
#        ' yes devidd', ' haha', ' 👍', ' lol', ' error', ' yeah same',
#        ' a shame', ' i know so was mine', ' right*', ' javid that is',
#        ' i need to see that', " i'm prorogue", " he's*", ' lol', ' yea',
#        ' yeah', ' lol yeah', ' haha', ' so true', ' lol. >twink',
#        ' yeah yeah', ' yeah yeah', ' yeah taylor', ' no thanks',
#        ' and you shall', ' 👍', ' i did enjoy that', ' 👍', ' yeah',
#        ' great story', ' ah shit', ' fuck it', ' yeah yeah.',
#        ' apparently', ' love it', ' yeah lol', ' lol',
#        " that's excellent", " they've got you", ' lol', " we don't know",
#        ' too obvious', ' 👍', ' this is brilliant', ' classic', ' ah',
#        ' definitely', " don't think so", ' lol', ' 👍', ' lol', ' no',
#        ' oh yeah', ' ?', ' yeah', ' yes', ' yep', ' yeah that’s fine lol',
#        ' yeah yeah', ' this is excellent', " yeah it's great",
#        ' am i right?!', ' nah', " that's got me", ' ah.', ' chuckles?',
#        ' yeet', ' used to be', ' nah*', ' fuck this', ' lol',
#        ' not anymore', ' lol what the fuck', " that's mental", ' wtf',
#        ' can’t believe it', ' fuck.', ' this is absurd', ' ah',
#        ' yeah see now', ' 👍', ' ah', ' ah', ' fuck', ' fuck yes', ' fuck',
#        ' fuck', ' fuck', ' amazing', ' fuck', ' yeah metreso', ' 👍',
#        ' so decadent', ' surely', ' haha', ' jesus christ', ' 👍', ' ah',
#        ' lol assou-ekotto', ' yeah yeah', ' just asking', ' nah', ' lol',
#        ' excellent', ' lol', ' finally', ' oh for fuck sake...',
#        ' agree on this', ' here here', ' true"', ' i am a fan', ' 👍',
#        ' ...', ' we’ll see', ' dinge lol', ' yeah', ' cheers boi',
#        " i can't wait.", ' i see', " and that's cruffts", ' haha', ' lol',
#        ' got it!', ' lol', ' lol', ' obviously', ' lol', ' yeah',
#        ' yeah y', ' no', ' yeah', ' possibly', ' yeah >tardigrades',
#        ' yeah yeah', ' not bad', " nevermind i'm in", ' no maupay?',
#        ' i have no idea', ' good to know', ' yeah yeah', ' lol', ' yeah',
#        ' yeah', ' yeah yeah', ' fucking kitson', ' yeah', ' massive',
#        ' huge.', ' it is known', ' yeah', ' lol', ' ok', ' sure',
#        ' ah right yeah', ' yeah yeah', ' it was known', ' yeah i agree',
#        ' love it', ' lol that’s great', ' 15 pts', ' yeah', ' lol',
#        " that's mental", ' that was brilliant', ' of ffs', ' ffs',
#        ' yeah yeah', ' ah number 10', ' ??', ' man', ' that’s great',
#        ' ah warney', ' that’s brilliant', ' jesus', ' pukk you sir',
#        ' i refuse', ' ah', ' yeah yeah', " i'm looking into it", ' no',
#        ' not so good', ' oh dear', ' more reasonable', ' lol', ' yeah',
#        ' 👍 cheers', ' yes.', ' yeah sounds nice', ' *you be', ' exactly',
#        ' yeah', ' no', ' yeah', ' in fact 4', ' haha', ' ah', ' true',
#        ' haha', ' 👍', ' decent', ' i understand.', ' nah',
#        ' is that same as mine?', ' 👍', ' just leaving', ' just left',
#        ' just left', ' now right', ' just arrived', ' yeah', ' lel',
#        ' yeah yeah', ' deep.', " it's great.", ' guess so', ' no', ' nah',
#        ' excellent', ' ah', " i'm considering it", ' nah not yet',
#        ' you tell me?', ' yeah quite cluncky', " i've put it in",
#        ' *make it', ' need deets', ' no rush', ' so bad', ' lol',
#        ' ah yeah', ' t', ' eh?', ' lol', ' yeah', ' good call',
#        ' quality?', " 'fun fact'", ' yeah yeah', ' 11%', ' complete shit',
#        ' 👍', ' yup', ' yeah', ' so selfish', ' yeah mental',
#        ' already working on it', ' ah', ' yeah yeah', ' trossard*',
#        ' won', ' kek', ' was massive', ' yeah i remember that',
#        ' fucking lol', ' lol', ' i ❤ cancer', ' but yes', ' nice', ' ah',
#        ' ah', ' really went all in', ' hah', ' yeah yeah',
#        ' was just about to say', ' how tho?', ' y tho', ' wat tho',
#        ' this is excellent', ' finally', ' oh yeah. immovable object',
#        ' ah. panic', ' good to see', ' lol', ' need that', ' i need that',
#        ' ooohhh jaaaack?', ' ah', ' yeah pretty much', ' i quite like it',
#        ' some still are', " that's the one", ' ah yes', ' yeah lol',
#        " yea i'm in", ' 👍', ' 👍', ' yeah started', ' yeah', ' yeah yeah',
#        ' link?', ' so on', ' great finish', ' yeah', ' yeah',
#        " and that's fine", ' just the best', ' no fucking shit',
#        ' ah yeah', ' 👍', ' i see', ' yes', ' ah', ' so true', ' 👌', ' ah',
#        ' we need that', ' nah.', ' oh yeah', ' lol', ' that answer',
#        ' nope', ' ha', ' lol.', ' that is disappointing', ' lol', ' yes',
#        ' yeah yeah', ' what?', ' i think so', ' then',
#        ' i would love that', ' very tory', ' yeah', ' yeah exactly',
#        " can't wait.", ' roughly', ' how so?', ' hmmm dunno', ' exactly',
#        ' ah. moy', ' yeah looks great', ' yeah yeah', ' sure sure',
#        ' great point that', ' lol bercow', ' lol',
#        " i'm in need of that too", ' yeah yeah', ' most likely',
#        ' absolute shit', ' finally', ' seems so', ' lol', ' fuck!',
#        ' ah there he is', ' yeah', ' trossard', ' oh yeah',
#        " you can't do that...", ' lol guendouzi', ' yeh', ' ?',
#        " i'd rather not", ' by law', ' is it certain?', ' ideally yes',
#        ' exactly', ' yeah yeah', ' ah', ' no.', ' lol no',
#        ' how about this instead?', ' very choice', ' yeah', ' exactly',
#        ' 👍', ' i suppose', ' lol.', ' lol. this got me',
#        ' had to be done', ' yeah probably', ' same', ' lol', ' ........',
#        ' lol >england', ' fuck off', ' 👍', ' ah', ' of course', ' yeh',
#        ' lol', ' ah', ' starting now', ' what?', ' where?', ' i’m on it',
#        ' huge', ' should be good', ' obviously', ' ah right',
#        ' very similar', ' lol', ' they know', ' which one?',
#        ' that is my point', ' extremely droll', ' lol that’s great',
#        ' very choice', ' lol yeah', ' sounds good',
#        " sadly i don't think so.", ' ah i love that', ' lel', ' kek',
#        ' lel', ' yes definitely', ' very pythonesque', ' ?', ' lol yeah',
#        ' agree', ' a handful', ' no of course not', ' lmfao',
#        ' naturally', ' agree', ' lol this is already great',
#        ' lol so shit', " i'd get one", " i'm sorry?", ' yep',
#        ' though i did make that', ' i would enjoy that',
#        ' yeah not too fussed', ' lol', ' lol', ' lol', ' lol pochetiino',
#        ' this is massive', ' must be', ' lol', ' feels right', ' lol',
#        ' lolz', ' is he in?', ' yep', ' ah this is great',
#        ' clearly your opinion there lol..', ' lol yeah yeah',
#        ' examples please', ' them*', ' lol', ' lol', ' yes',
#        ' lol this would be great.', ' lol', ' haha', ' lol',
#        ' was considering this', ' does not compute', ' lol',
#        " i'm sorry?", ' clearly', ' 👍', ' here here', ' you up there?',
#        " it's all set up", ' ah', ' ah', ' got to go', ' lol',
#        ' thank god for that.', ' oh huge', ' no', ' yeah', ' very finchy',
#        ' 👍', " there's a lot about", ' lol', ' lol', ' lol yeah yeah',
#        ' 👍', ' yeah', ' spot on', ' yeah agreed', ' lol', ' ah yeah.',
#        ' lol', ' wow', ' nah', ' very nice', ' ah what?', ' nah mate',
#        ' everyone', ' lol', ' ...is best', ' *excuse this',
#        ' ah... useful info', ' yeah mccintye', ' yeah', ' lol',
#        ' yeah very grotty', ' never been', ' yeah i think so',
#        ' lol that’s great', ' it is rather amusing that', ' lol', ' lol',
#        ' ah ok', ' lol just thinking that', ' er how?', ' spot on.',
#        ' fuck', ' yeah exactly.', ' fuck off', ' (and die)', ' amazing',
#        ' 👍', ' yeah i saw', " and it's done", ' ah ded', ' no',
#        ' lol is this a thing?', ' yeah', ' lol 👍', ' dat*',
#        ' very excited', ' yeah', ' no', " we're back", ' yeah', ' lol',
#        ' they got me', " i'm cool with this", ' lol', ' which is?',
#        ' sounds shite', ' yeah yeah', ' lol that’s excellent',
#        ' yeah this was it', ' ah.', ' even better', ' this is great',
#        ' excellent', ' lol', ' 18 then', ' 👌', ' lol', ' reckon so',
#        ' fuck sake', ' yeah', ' finally', ' yeah yeah',
#        ' fucking layabout', ' lol what?', ' this is brilliant',
#        ' correct.', ' haha amazing', ' yeah', ' the suspense', ' lol',
#        ' lol', ' tell me about it', ' yeah i would think so', ' yeah',
#        ' definitley', ' must be.', ' lol', ' ah yeah forgot that', ' 👍',
#        ' 10mins to go', ' fuck', ' holy fuck', ' lol', " i'm down.",
#        ' yeah but', ' lol', ' sure', ' sounds about right.',
#        ' something like that',
#        ' no https://www.google.com/amp/s/amp.theguardian.com/politics/live/2019/dec/10/general-election-swinson-says-johnsons-rhetoric-puts-eu-citizens-at-risk-of-hate-crimes-live',
#        ' ?', ' lol', ' is that a given?', ' lol', ' lol yeah', ' ah',
#        ' lol', " isn't swinson also doing that?", ' how about that...',
#        ' haha true', ' very throaty', ' lol yeah', ' nice', ' ?',
#        ' altogether*', ' very damo-esque', ' yeah', ' i’m here',
#        ' on my way', ' ahh', ' nah.', ' lol', ' very gouty', ' lol',
#        ' yeah yeah nice and horrific', ' outstanding', ' oh god',
#        ' great', ' yeah yeah', ' quite discordant', ' what the fuck',
#        ' that’s griff', ' same', ' oh yeah.', ' lol', ' lol',
#        ' yeah yeah', ' yeah', ' ah i like that', ' lol', ' that minute.',
#        ' yes', ' yes', ' 👌', ' -45 actually', ' that is not the way',
#        ' it’s been years', ' fuck this', ' lol', ' nice', ' yep',
#        ' yeah yeah', ' it’s johnned me', ' ah', ' yeah yeah', ' yeah',
#        ' yeah very annoying', " i'm trenting", ' gonna be huge', ' it is',
#        ' ah yeh is', ' yaaas', ' as i said', ' yeah yeah', ' no',
#        ' very cloying', ' lol', ' nah', ' lol', ' lol',
#        ' this has got me', ' lol nah', " that's baffling",
#        ' what is this???', ' very close', ' bravo',
#        ' nah. sometimes excellent', " lol that's great!",
#        ' lol that is so shit', ' cheers mate', ' lol', ' what did?',
#        ' yeah lol', ' lol amazing', ' the classic',
#        ' actually very appropriate', ' lol nah', ' wait a minute',
#        ' sorry', ' dat', ' sounds awful', ' lol', ' ah.', ' yeah yeah',
#        ' excellent', " he's just doing that.", ' yeah', ' nah',
#        " that's great", ' yeah yeah', ' huge', ' too much',
#        " no i haven't", ' yep', ' yeah', ' yes', ' good description',
#        ' this is spot on', ' lol', ' yass', ' lol city', ' 👌', ' 👌',
#        " yeah it's brilliant", ' sucks*', ' bad', ' i believe',
#        ' i agree', ' 👍', ' this', ' yeah', ' excellent', ' classic',
#        ' sounds great', ' first 30mins', ' that reciept', ' nah', ' fine',
#        ' yeah', " yeah it's goid", ' agree', ' yeah', ' yes', ' perhaps',
#        " i'll watch", ' lol', ' yeah', " ...and we're out", ' nah',
#        ' oh wow', ' fuck that', ' yep', ' for a few days', ' this',
#        ' better', ' yep', ' ah', ' nah', ' link', ' same', ' congrats!',
#        ' congrats!', ' yes', " that's it", ' nice', ' loving it', ' nice',
#        ' 👍', ' ... ok just me...', ' fuuuuuck', ' what is this?', ' ah',
#        ' haha', ' yeah', ' it is ebin.', ' obviously not', ' in theory.',
#        ' lol', ' obviously shit', ' one word', ' boom', ' boom',
#        ' correct', ' ah yeah', ' also... .', ' ah. there we go', ' yeah',
#        ' nice', ' i have two', ' yeah this', ' yep', ' yeah yeah',
#        ' old news', ' lol', ' lol', ' we’re fine', ' same', ' ah',
#        ' can’t be it', ' surely not', " but i'm fine now", ' lol', ' nah',
#        ' hah', " don't think so", ' lol', ' and*', ' lol',
#        " that's got me", ' better version', ' lol', ' you can have that',
#        ' fine.', ' lol.', ' lol', ' haha', ' haha', ' lol', ' yeah yeah',
#        ' yes.', ' not yet', ' yeah', ' yeah', ' of course', ' naturally',
#        ' what is this?', ' but why?', ' yes?', ' should be doing that',
#        ' yeah same here', ' lol', ' a', ' couldn’t possibly be it',
#        ' this grot', ' oh ffs', ' good point', ' yeah yeah', ' this',
#        ' nothing', ' ah', ' yep', ' lol', ' yes', ' *so', ' dick move',
#        ' it', ' no', ' this is well established', ' ok superspreader',
#        ' i missed that', ' lol please elaborate', ' lol typo', ' lol',
#        ' ah', ' just sensible', ' yes ani', " can't have that",
#        ' yeah yeah.', ' yeah.', ' ah.', ' massive', ' no idea', ' lol',
#        " that's got me", ' lol', ' lol', ' ah that’s good', ' that lol',
#        ' good luck lol', ' there is always that', ' nah', ' think so',
#        ' lol', ' yeah', ' lol', ' damps it down', ' you cretin', ' lol',
#        ' like what.', ' oops', ' 5 minutes ago!', ' lol',
#        ' yeah thank christ', ' that’s coffee', ' already exists', ' fuck',
#        ' yeah', ' ah', ' not yet', ' yeah massive', ' lol',
#        " this is what's happening", ' exactly', ' ah', ' no', ' no',
#        ' everyone in', ' very good', ' anyone else?', ' yeah',
#        " but he's right", ' lol', ' that’s a fact',
#        " that's shit as well.", ' over it', ' yep', ' too*', ' where?',
#        ' yep', ' 5', ' not this again', ' not convinced',
#        ' yeah. impossible', ' quite likely', ' excellent', ' 👍',
#        ' possibly', ' lol', ' actually really shit', ' ah',
#        ' me too actually', ' lol', ' very close', ' lol', ' happened',
#        ' nah', ' no way.', ' yeah a week', ' may need this', ' lol',
#        ' lol', ' also lol', ' ah.', ' no', " they haven't", ' fuck',
#        ' nah', " lol i'm getting it", " that's outrageous", ' not*',
#        ' ah', ' `', ' wtf', ' +-', ' ---', ' -', ' ah. lol', ' lol', ' 1',
#        ' 100%', ' strong', " lol that's rediculous", " that's got me",
#        ' ah', ' what do', ' good point', ' this got me', ' yeah love it',
#        ' ?', ' wrong thread', ' no way', ' lol', ' on point', ' so 1800s',
#        ' there you go', ' it’s something i guess', ' lol classic',
#        ' winner', ' shame', ' why?', ' no.', ' fuck', ' the end', ' lol',
#        ' 15mins to go', ' love this', ' lol', ' (i think it did)',
#        ' right. yeah', ' this is uk', ' is*', ' no not neccesarily',
#        ' possibly', ' but i might not be', ' ah.',
#        ' are you away from that?', ' yeah yeah yeah', ' 👍', ' i can*',
#        ' yeah lovely day', ' lol', ' nah', ' actually very shit',
#        ' yeah incredibly shit', ' lol', ' first to go', ' lol such as',
#        ' not so far', ' nah', ' lol', ' oh john', ' *were', ' yep',
#        ' ah balls', ' yeah yeah', ' here we go', ' 👍', ' yeah has to be',
#        ' that would be fun', ' lol that sounds great', ' lol',
#        ' yeah would enjoy that', ' oh john', ' lol', ' lol',
#        ' good bit of news', ' ah yeah', ' sauce?',
#        " lol that's brilliant.", ' ?', ' oh john', ' meh grogodoines',
#        " that's mental", ' at the same time', ' wellll.', ' ah', ' lol',
#        ' again!', ' ah', ' the what?', ' lol', ' no', ' lol', ' correct.',
#        ' yes.', ' very.', ' ?', ' 👌', ' hah', ' nah',
#        ' lol this is true now', ' good book as well', ' ah',
#        ' absolutely', ' ?', ' source?', " yeah that's the issue",
#        ' yeah obvs', ' yeah yeah', 'Yeah you could', 'Yeah I think so',
#        'Sure', 'sorry', 'ahhhh... my mistake', 'Like 10 mins', 'means OK',
#        'Yeah I did all that', 'Is that all?', '*shit', '??', 'Nah 3',
#        'Lol', 'Lol this too', 'Hi Stefan', 'Late reply, but yeah',
#        'Sounds legit', 'kek', 'Nah', 'Yeah there we go', 'Not at all',
#        'No', 'Lol. #priorities', 'Haha', 'Cheers', '', 'Ding ding ding',
#        'Lol', 'Very grotty', 'classic', 'You know', 'Could be good', '',
#        'Hello???', 'Very very convenient', 'Absolutely not', 'Nope',
#        'Lol I remember that', 'Woof', 'Marvellous', 'LOVELY', 'Dunno...',
#        'Yeah something like that', 'Hahah', 'Good result', 'Nah', 'Yeah',
#        'No', 'My man', 'Well exactly', '*do', "I'll give it a go",
#        'ah...', 'Me too', 'Also', 'Lol', 'No.', 'Uh oh.....',
#        "Don't like it", 'Lol. No idea', 'Fuck off', 'Ummmm.....', '',
#        'Kek', 'Lol', "That's... unfortunate", 'Ah.', 'No', 'Shit storm',
#        'Nah', 'Lol what? He is good.', 'And shit', 'Wut?', 'Cheers boi',
#        'Yes please', 'Lol tarrant', 'Yeah bring them', 'What?',
#        'Bon. Jour.', 'Anyone else?', 'Yeah boiy', 'Yes', 'Also',
#        'Very able', "I can't put it down", 'might*', '!!!',
#        'Ah fair enough', 'Yes', '(Yes we are)', 'y', 'Why?', '?', 'No!',
#        'No reason', 'Why this time?', 'Same', 'For damoâ\x80\x99s sake',
#        'Lol', 'yes please do', 'Lol', 'Lol', 'So', 'lol', 'I love this',
#        'Lol', 'Yes.', 'Lol', '*too', 'Where?', 'No', 'Lol', 'Lol >sziget',
#        'Lol 39 days', 'Lol', 'I do', 'Lol', 'Ah', 'Lol',
#        'This is bullshit', 'Evidently.', 'Lol', 'Lol', "C'est magnifique",
#        'Yeah yeah', "I'm loving it", 'it', "I'm loving", 'Go on',
#        'Ah there we go', 'Shit well', 'Never heard of it',
#        'May have posted that before', "No I haven't", 'Classic', 'Lol',
#        'lol same', 'Shit', 'Decent', 'Yeah I read that lol', "I'm crying",
#        'Massive', 'not sure', 'obviously', '?', 'Yeah', 'Hah',
#        'My face when', 'Yeah lol', 'Yep', 'Sweet', 'Very un4tun8 m8',
#        'M8, pls', 'Ok m9', 'M8', 'Gr8', '?', "That's the one", "I'm up",
#        "It's pretty good", 'Know it well', 'Boom', 'DANK', 'No not yet',
#        'Yes', 'Lol what the fuck?', 'Not sure', 'It is', 'You',
#        'Shit away', 'lol', 'Also', 'Yeah fleshy', 'R.I.P', 'Lol', 'Ah',
#        '?', 'Not sure', 'Impossible', 'Fuck that', '*least',
#        'And yes. I have', 'Sick of it', 'Psst', 'Ey', 'On?', 'So blooter',
#        'Got it all wrong', 'Yep', 'It is', 'Yeah yeah yeah', 'Gotcha.',
#        'Yeah', 'Lol true', 'Glorious', 'Absolutely gasping',
#        'Ummm hello?', "Yeah it's great", 'Wow', '', '', '1-0', 'Bad',
#        "Yeah that's alright", 'But absolutely', 'That ones great', 'Yes',
#        'OOOH', 'Lol', 'No', 'Lol.', 'Too long', 'Sounds legit',
#        'Yeah for definite', 'Yeah yeah yeah', 'Lel', "That's mental",
#        'Haha', 'Garbage', 'Yeah I thought that', '', 'Obviously', 'Yeah',
#        'Um hello', 'It has', 'Ah wait', 'Lol', 'Sounds good', 'Oh yeah',
#        'Ummm hellooooo', 'Ah yeah good point', 'On the left',
#        "I'll get on it", 'Very little I think', 'Ah', 'Classic',
#        'It is known', 'Yep', 'And I agree', 'Surely...', '..or is it',
#        'I', 'I am', 'Lol', 'Ah yeah. Checks out.', 'Hard to say',
#        'Oh yeah', '"meh"', 'Yeah kek', '', 'Yeah I think so', '*Kek',
#        'ah yeah.', 'Deep.', 'Yes.', 'Great', 'But really?', 'Yeah',
#        'Really?', '*yet', 'lol', 'Yep sure', 'So cool man',
#        'Sorry, the river', '', 'Um, hello', 'LOL', "That's a classic",
#        "Certainly, it's NW1.0", 'Want', 'Fucking Â£75', 'Yeah saw that',
#        'Ah', 'We need this', 'Lol. Clavonte', '>not we', 'There he is',
#        'Yeah googled that', 'Lol', 'Ah', 'They really are', 'Aberconwy',
#        'So Paul', 'Come on...', 'Haha', 'Yeah saw that', 'lol', 'lol',
#        'lol', 'True', 'Yeah', 'Surely bollocks?', 'Shit', 'Lol', 'Ok',
#        'Exactly', 'Always.', '', "Can't*", 'Lol', 'Yeah', 'Are you?',
#        'Hi nichola', 'Lol, true', 'Ah', 'I cared immensely', 'Cheers',
#        'Kek', 'Yes I imagine so', '*and', "I've got some of this..",
#        'Ok let me know', 'Not sure', 'okay cool.', 'What is this?',
#        'Shit storm', '', 'Ah yeah', 'Yes I think so', '18 actually',
#        'Dat dat', 'Yep.', 'Maybe not 5', 'Looking great', 'Yeah',
#        'I have 16/16', 'Excellent', 'Lol this is great', '',
#        'The former.', 'You are right', 'Wut', 'Kek', 'Done it', '',
#        'Oh snap', 'Lol', 'Yes for me please', 'Me too', 'Pretty good',
#        'Yeah yeah yeah', 'Not sure', 'No skill', 'Very good news',
#        'Fuck that', 'Ditto', 'Me too', 'Same for me then', 'No idea',
#        "Yeah I'll go for some", 'please', 'Ok...', 'Fuck you',
#        'Heard good things', 'A couple of times', 'GET IT', 'Goodness',
#        'Both actually', "It's begun", 'Makes sense', 'Sure', 'No',
#        'You can', 'The end', 'Lol', 'Lol no', 'Lol',
#        'That is so specific', 'Lol', "That's a tough call",
#        'might be interested in that', 'Hmm', 'MY DICK', 'Lol',
#        'Very droll', 'No', 'Also', ':0', 'Ah', 'At least 2', 'Explain',
#        '', 'Lol', '', 'We do', 'Surely Wexit?', 'This game', 'Um hello?',
#        'Just googled it', 'Not true', "Trollin'", 'Nice', 'Yeah',
#        'this guy', 'U wot?!', 'hmmm, surprising', 'Hit me', 'Yeah', '',
#        'Lol', 'There it is', 'Haha >this guy', 'Very good actually',
#        'Yeah', 'Pussy', 'lol', 'Very Withnail', 'Still alive',
#        "Ok. I'm going for it", 'Obviously', 'Lol', 'Didnt go well',
#        'Obviously', 'Ummm hello', 'Boom', 'Yes that would be good',
#        'Such timing', 'Lol', 'Wtf', 'Here we go', "He's off", 'Yeah',
#        'yeah yeah', '', '', 'Excellent', 'Brilliant', 'Lol', 'Yeah',
#        'You idiot', 'Correct', '', '', 'Also', 'Yeah yeah yeah',
#        'Sweet, booked.', 'Yeah fine for me', "That's OK for me",
#        'Fine for me.', 'Works for me', 'Thats fine for me', 'Lol',
#        'Love it.', 'Yeah yeah yeah', 'No.', 'and it was good',
#        'Sounds good', 'Do you?', 'I do fancy it', 'yEAH', 'yeah',
#        'But yeah', 'Derp', 'haha', 'Yeah yeah yeah', '', 'Yeah',
#        "It's garbage", 'What?', 'Â£4. lol.', 'MOTHErFUCKER', '(I am)', '',
#        "I'm working on that", 'how about now?', 'Hmmm', 'ah I see',
#        '?oh really...', 'This is unexpected', 'Completely', 'Also',
#        'Get here', 'Wot?', 'Ok no worries', 'Yes', 'Haha', 'Dear lord',
#        'Oh doctor....', 'NOPE', 'Ah. Postal. Obviously', 'Yeah yeah yeah',
#        'On my way now', 'Yes', 'Two words', 'This conversation', 'Eh?',
#        'Here he is', 'Yeah yeah yeah', 'U b?', 'Let me know',
#        '*straight up', 'Very disappointing', 'Haha', "I'm about.",
#        'Yeah, yeah yeah', 'Yeah yeah yeah', 'Of course', 'Nah', 'No',
#        'Kek', 'Yeah', 'No just there', '14 also', 'Not me', 'yeah lol',
#        'Lol', "I don't understand", 'Lol', 'Lol', 'Dear god', 'Bugger',
#        'Lol', 'that is quite something', 'Nice work', 'Google it', 'lol',
#        '', 'Please continue', 'Very', 'Fuck sake', 'yeah', 'also',
#        'Here we go then..', 'its on now', 'Good song', 'Sorry to hear it',
#        'B-B-B-Brexit yo', '?', 'very grotty', 'So awkward', 'to bad',
#        'link?', 'Lol', 'That was good', 'Lol', 'Oops', 'Yeah',
#        "That's the one", "That's the fact I want", 'Lol', 'Did it?',
#        'dont want it*', 'Just testing', 'ummmm hello?', 'Lol', 'does he?',
#        'Actually', 'No', 'Yea, yeah', 'Oh doctor', 'ummm..... no.', 'It*',
#        '', 'ummmm hello?', 'Fuck.', 'ah. very very grotty',
#        'Ah Burny Naanders', 'Ah. Too much.', 'Fuck off', 'And where',
#        'rip', 'What is this?', 'Ummm. Hello?', 'Ah', 'wut', 'wut', 'Lol',
#        'Oh dear...', 'What', 'Fucking brilliant', '', 'Lol. Daffy',
#        'fuck this', "I'm unaware", 'wut?', 'Yeah I know', 'No. Wait.',
#        'Lol', 'Hmmm dubious', 'But it should?', 'Who indeed', 'Lol',
#        'Lol', 'Damo no', 'No shit', "That's the one", '*its', 'No right',
#        'Here he is', 'Very cheeky', 'Lol', 'Ah I see',
#        'In relation to what?', 'For why?', 'How much?', 'lol',
#        'Yeah yeah yeah', 'Ah', 'oh, bravo', 'This is true', 'All fine',
#        "'Might'", 'Haha. That makes more sense', '1-1', "It's true",
#        "*can't", 'Still would', ':-/', 'I did not', 'Indeed!', '', 'lel',
#        'oh yeah.', 'hello?', 'um. rainbow?', 'lol', 'Very, very droll',
#        'Very droll', '', 'LOLOLOL', 'Yeah, probably.', 'Tempting...',
#        'No', 'Um. Ah. Hello!!??', 'lol', 'So this happened...', 'Cheers',
#        '', "It's Â£1350 apparently", '', 'detectorists then', 'yeah.',
#        'Lovely', 'lel', 'Wtf?', 'that feel', 'Absolutely massive',
#        'I could come', 'Wtf', "That's big", 'Lol', 'He was right',
#        'Not sure', 'Good point', ':(', 'im sorry',
#        '4 times over, apparently.', '', 'plus', 'fucking hell.', '6',
#        'Hahahaha', 'I cannot even', '(in the video)', '?', 'Not as good',
#        "Yeah that's the one", 'just why.', '', 'This utter shit', '',
#        'errr.... no idea', 'Lol', 'Fuck sake', 'LOL', 'lol.', 'Nah',
#        'Goal?', 'Lol', 'lol. yeah.', 'lol', 'noice', 'What a man',
#        'Uh oh', 'haha', 'Yeah, that works.', "Ah no it's there",
#        'Alright', 'Lol', "I can't wait", 'What is it?', 'In',
#        'Make it so', "I'm already in", "I'm in", "Yeah I'm in",
#        'Works for me', 'yeah may as well.', 'That is hugely shit',
#        'It is known', 'It is known', 'Agreed', 'Lol', "It's decent.",
#        "Yeh that's definitely happening", 'Not bad', 'Explain',
#        'Fantastic.', '', 'It is known', 'It is known', 'It is known', '?',
#        'Lol.', '', 'um hello.', 'Also:', 'Haha', 'Great.', 'Saw that lol',
#        'Ah yeah', 'thanks.', '', 'lol', 'Great idea',
#        "I don't see the issue", 'Just tad', 'This is absurd', 'No',
#        'Has that got to you?', 'Ha', 'This game', '*good',
#        'Obviously yes', 'Lol', 'Ha', 'Ah. Mataberg', "What's happening",
#        'This game.', '6 of one', 'Haha that sounds great', 'Yeah', 'LeL',
#        'l', 'Very trolly', 'Very spursy', 'Lol', '*in', '',
#        'here we go then', 'Yep on now', 'Shit', 'Lol', 'Yes!!!', 'No',
#        'Yes! Hgghn', 'Ah', 'This game', "that's great.", "that's great",
#        'lol', '?', 'haha', "that's crufts", "that's fucked", 'obviously',
#        'I have', '??', 'ah', 'still 2009?', 'then', 'no', 'unfortunately',
#        'yeah yeah yeah', 'fucking nonesense', 'Not even that much',
#        'yeah.', "that's utter shit", '2-0 then', 'Ah yes', 'lol',
#        'obviously', 'ha', 'um... yes!', 'Lol', 'you woud though',
#        'still.', 'hold on', 'these are great', 'haha, no', 'fuck',
#        'not bad..', 'Got it', 'haha', 'This is big', 'though', '',
#        "That's crufts", 'tonight fam.', '', 'dem', 'on the piss?', 'Lol',
#        'GOAL', '', '*do you', 'Nice', 'to be fair', 'lol',
#        'So much Wenlock', 'thats because...', "i'm all over that",
#        '>Â£2.50 please', 'Yeah lol', '*be', 'Was just thinking that.',
#        'Ah', 'Yes', "(It's great)", '', 'lol', 'this is in', 'Classic',
#        'hahaha', 'lol', 'Lol', 'this gurn...', 'Lol. What indeed.', 'lol',
#        'original', 'oh god', 'ah.', 'Absolutely twated it', 'holy shit.',
#        'classic', "What's happening?", 'Damn', 'fuck', 'very bad.',
#        "I'm out", 'Assume so', "That's massive", '6 I think', '',
#        "I'm around.", 'This game', '', 'I would', 'Hah', 'Also', '', '',
#        'this guy...', '', 'Lol.', 'That stinga', 'Cheers mate',
#        'I johned it', '', 'ah yeah that guy', 'ha', '[Very droll]', 'Lol',
#        'you all right there mate?', 'And this ^', 'haha', 'Very droll',
#        'I could do either', 'Very droll', "Are you sure it's me?", '',
#        '6 minutes of that.', 'you what?', 'Quite ridiculous',
#        "I don't get it...", 'Ha', 'Thanks', '', 'You could do',
#        'That would be g#', 'It is a good one yeah.',
#        'All the way through', 'have it mate', 'not interested..', '',
#        'Sounds good', 'Sounds good', 'Yep', '', '*proper', '', 'Link?',
#        'Yeah yeah', '*tis.', 'Ah ok', 'Works for me', 'Cheers boy',
#        'Yeah', '*shit', '*we should', "I'm about", '', '?',
#        'ha, well fair enough', 'yeah', 'what the fuck', 'Yeah yeah yeah',
#        'Ah', '', "That's not the same", '*top 4', 'yeh exactly',
#        'Just looked it up', 'Oh that would be lovely', '?', '*last 5',
#        'Ah, snap.', 'ha, nice.', 'nope', '', 'too good', '* are', '',
#        'Lol Phil', 'Only just saw this. Oh well.', 'Gosh', 'Ffs.', 'Yes',
#        'Um hello', 'oh wait....', '', 'you bellends', "That's a bummer",
#        'Serious?', 'Great lad', '*ill', 'That is excellent',
#        'this is great', 'Eh?', '', 'fucking 3', 'this is excellent',
#        'Obviously', '', 'yeah', 'yeah yeah yeah.', '', 'I feel yes',
#        'Does it?', '*my', '', '', 'Oh yeah', 'Brilliant',
#        'yeah pretty good', 'Indubitably', 'Lad', 'Oh yes.', '', ':)',
#        'Fuck', 'Amen', '', "I'm in", 'Haha', 'brilliant', 'Yeah',
#        'here we go', 'Haha', 'K. Will do', '', '>giving thanks',
#        'is he kidding?', 'that fucking chap', '', '', 'lol >whiteout', '',
#        'Still shit', 'It did work', '', '', 'Je suis 7', '', 'Great chat',
#        'haha', 'Lol', 'Fucking brilliant', '', 'Undoubtedly',
#        'Aye up lad', 'Well that is excellent', 'so broken...', 'Lol',
#        'Cheers mate!', '', '', '', 'um, hebib.', 'Oh yeah',
#        'I presume so', 'Haha', 'that be mine', '', 'this is big',
#        'Yep, sounds good', "Yeah that's cool", 'Excellent', 'Cheers', '',
#        'no.', '*is Io', 'Very grotty', '*what*', ':(', '', 'Sweet as bro',
#        'its synching', 'Works for me', '', 'Haha', 'alrighty',
#        'fuck sake', 'um.. hello?', 'Ah my bad, it does', 'quite', 'Yeah',
#        'lol', '', 'oh doctor', 'And you?', 'No.', 'Haha', 'lol', 'strong',
#        "that's tickled me", 'Hehehe', 'Oh my...', 'Massive',
#        'That is huge', 'Lol', 'Yes!', 'Here he is!', 'yeh yeh yeh.', '',
#        'henderderson. lol', 'Yeah like that', "I don't need this.", '',
#        '', '', 'nah. cirrussly?', '', 'hehehe', 'lol', '', '', '',
#        'So shit', 'lol', 'So yes', '', 'just taking a minute.',
#        'This guy', 'Haha', 'Oh Doctor.', '', 'true dat', 'agreed',
#        'yes please', 'Sounds good to me', 'top lel', '',
#        "that's brilliant", '', 'disgusting...', '', 'that guy...',
#        '... I was just thinking that...', '', 'LOOOOOL', '',
#        'yeah yeah yeah', 'sounds great', ':)', 'yeah, good plan',
#        'not to me.', '', 'fuck sake', 'shit', 'This.', 'OH',
#        'This is too good', '', 'yes', 'put it right up you.', 'haha', '?',
#        '', '', 'hahahhaa', 'haha YES', 'love it.', 'Lol', 'lol',
#        'thats tickled me.', 'lol', 'haha', '', 'This is too good', 'Haha',
#        'Yeah yeah yeah', '', 'lol', 'lol', 'top bloke.', 'Great buy',
#        'Nice', '', '', '', '', 'ah', '??', 'What is going on', 'Hah', '',
#        '', "That's mine", '', 'haha', '', '', '', 'huge',
#        'yeah yeah yeah', '', 'WTF', '', '', 'so good', 'Cheers', '',
#        'lol', '',
#        'Oh Ballack!http://lm.facebook.com/l.php?u=http%3A%2F%2Fwww.youtube.com%2Fwatch%3Fv%3DS_TnriZoEvc&h=_AQG7aThS&s=1',
#        'brilliant', 'lol', '', 'Very Grutty', 'oh shit', 'But*',
#        'oh dear..', 'YES', '', 'MEGA LOL.', 'lol', 'Would do though.',
#        'nah', 'noice', 'I already have it', '', '', 'Very very grotty',
#        'very grotty', '', 'thank you', 'you had my interest.',
#        "yeah that's right", 'yep', 'Yep', 'yeah alright', 'Lame',
#        'Very good', 'Oh dear', 'yep', 'thank god for that', 'nice', 'Yup',
#        'Yep', 'lel', 'me too', '', "that's so horrible", 'lol', 'kek',
#        'Lol', 'Come on', 'Monbeg dude', 'just heard it',
#        "haven't heard it", 'Dick*', 'jesus', 'Very nervous', 'woof',
#        'Cheers', '', 'haha, yeh yeh yeh', 'The original', 'who is',
#        'fine here', 'Works for me', 'Me too', 'Good with me', '', 'Loool',
#        'Also....', 'oh here he is', 'yeah sounds good', '', '',
#        'likewise', 'Cheers boi', '', '', '', 'cool', 'yes', '', '',
#        'yeah massively', '', "That's it", '', 'This guy',
#        'Yeah yeah yeah', 'Yeah x3.', 'yeah. where?', 'Lol', 'woah',
#        "'ah'", '', 'yeh yeh yeh', 'nah probably not', 'dont you mean',
#        'massive', '', '*s', '', "I've got one", 'shit son',
#        'Yeah yeah yeah', 'yeh. yeh. yeh', 'That is ridiculous', 'top lel',
#        'this is brilliant', 'got 26', 'you there?', 'YES', '*many',
#        'nice', 'fantastic', 'Cool', 'Me', 'yes', '', '', 'Hahaha',
#        'fucking lol', '"im absolutely gutted"\n', '',
#        'this is fucking great', "Yeah that's big",
#        'totally agree with all of that', '', "'thezza' surely?", 'nice',
#        '', 'Correct', '*is this the', '', '*:)', ':0',
#        'oh yeah, course. ', '?!?!?!', '...yes ', 'well im convinced',
#        ':D', '', 'so cute', 'hahaha', '', 'lolz',
#        "then there's this thread", '', 'lolz', '', '', '', '', 'Ok cool',
#        'pm. Thanks', 'Ha', 'nah nah nah', 'Which is ridiculous',
#        'Just been informed', 'top lel', 'WHAAAAAT', 'Ah. ', 'Ooh pub', '',
#        'Ah here he is', 'where is that?', '8am ish', '', '', '',
#        'what?!?!', 'Hehe', 'Hehe', 'Haha women...', 'fuck off', '', '',
#        'no', 'bit much?', 'Lol, ince\n\nBayol time..', '',
#        'yeh. thanks but no thanks', 'Finally', 'Hahaha', 'I lol that',
#        'lol. ', 'looool', 'yeah, incomprehensible', 'Heh, of course',
#        'uh oh', 'this is very funny', 'sigh..', 'thanks paul',
#        'Yeah yeah yeah', 'ok. but not for me.', 'nah nah nah nah',
#        "Obviously,  I'm at work", 'AAAH', "that's good pr.", 'hahahah',
#        'That is excellent', 'classic', 'this guy', 'yeah yeah yeah',
#        'WTF!!!!!!', '', '', 'i knew it!', 'Amazing', '', 'yes', '....not',
#        'here we go', 'Yeah', 'whaaaaaaat', "That's fucking Amazing", '',
#        '', 'no', 'oh doctor\n', 'thanks', 'Yeh ', 'Anyone there yet?',
#        'no', '', 'Lol dave', 'Unbelievable', '1st', "ah that's excellent",
#        'haha', 'Righto', 'Yeah x3', 'Yeah x4',
#        'What are you talking about', "oh god, i don't know", '?',
#        'Johned indeed', "can't happen. ", 'nahhh', 'lol', '', 'Wot', '',
#        'noice ', 'this guy.', 'Back right now?', 'oh look', '',
#        'yes I do',
#        'firstly. http://www.youtube.com/watch?feature=endscreen&v=IWegh6TRx6c&NR=1',
#        '', 'Absolutely not ', 'Whaaaa?', '', '', '', 'this is true',
#        'lol', '', 'hahah', '', 'just saw that as well', "that's amazing",
#        'Yes.', '', 'lel', 'how about', 'This guy ', 'whats this?',
#        "Yeh I'm ready ", 'fucking lel', 'Hehehe.', '.... i have no clue',
#        'schweet.', 'u wot m8', '', '', '', '', '', '', 'top lel!',
#        '"I\'d hit that"', '', '', 'correct ', 'of course ',
#        'Oh. Fucken!...', 'Sorry wupam', 'this guy', '', '?', 'L8rs m8 ',
#        'This guy', 'nice. ', '', 'good morning', 'noice', '', '', 'what?',
#        '', 'lol', '*part of me', 'this guy', 'top  lel', '', 'very close',
#        'fuckin...', 'fuckin..', 'LOL', '^^that guy', '^this guy',
#        'Top LeL', 'Good call', '..... what?!?!', '*be good', '',
#        'oh dear', 'Fuck me ', '', '', 'good investment?', 'that guy',
#        "it's going that way", 'very close', 'obviously', '', '', 'same',
#        "oh i didn't see that ", "I'm up for that!!", '', '', '', 'no',
#        'thats fucked.\n\n', '', '', 'yeah', '', '', '', 'haha',
#        'a bold move.', '', 'everything', 'implying?', 'lol', '*:(', '',
#        '', '', '', '', '', '', '', 'hahahahahaha ', '',
#        'oh god. madness\n', 'indeed', 'thank god for that', 'lol',
#        '<3 <3 KOP <3 <3', '', '', '', '', 'lol', 'derp', '',
#        'I think not ', 'Hmm', '', 'This guy', 'I like it ', '',
#        'cheers boi.', 'lol',
#        '[[188148481322322]]\x0c[[188148504655653]]\x0c[[188148501322320]]\x0c[[188148477988989]]\x0c\n[[188148494655654]]\x0c[[188148484655655]]\x0c[[188148497988987]]\x0c[[188148474655656]]\x0c\n[[188148487988988]]\x0c[[188148491322321]]\x0c[[188148651322305]]\x0c[[188148647988972]]\x0c\n[[188148644655639]]\x0c[[188148654655638]]\x0c[[188148657988971]]\x0c[[188148714655632]]\x0c\n[[188148721322298]]\x0c[[188148717988965]]\x0c[[188148727988964]]\x0c[[188148724655631]]\n\nluck then. ',
#        'ITS SWELL', 'fair enough', '', '*so', 'Do tell', 'yeh. yeh. yeh',
#        'likewise', 'faggot', 'excellent.', '', 'ROFL', 'erm ',
#        'just like that', 'awful', 'really', 'what do', 'is it?',
#        'well we should', 'good', 'it must be', 'sounds brilliant',
#        'think so', '', '', "'that's fucked'", 'So true\n', '', 'lol',
#        'book it', '', 'He is on here.', 'literally', 'i wish',
#        'good donners', 'but i think it was good', 'but',
#        'im sure you have', 'looks ok', 'tonight', '', '', 'i like this ',
#        'both..', 'Classic ', 'how much?', 'naughty', '>this guy', '',
#        'nah hamish', "'You'", 'I SAID NO.', 'Hehehe', '?', 'wut', '',
#        'I lolled that', '', 'Yeah', 'Yep ', '', 'bye', 'oh dear',
#        'oh god', 'yeh possibly', 'oh yes', 'haha', 'brb', 'error',
#        "i've got him in", 'possibly', 'ok', 'pick me up?',
#        "I'm going for me", '', '', 'this is massive', 'shit storm',
#        'Not a problem', 'err probably ', 'not me', '', '', 'also',
#        'ok cuty ', 'excellent...', 'yes', '', 'thats a keeper', '...', '',
#        '', '', '', '*another', 'LOL', '', 'your choice', 'lol', '',
#        'fucks sake', '', 'go on...', 'nah', 'of himself', 'excellent',
#        'fuck off', 'but paul....\n', 'hoot indeed.', '',
#        'lol seen that before', '', 'mega lol', 'haha', '?', 'done', '?',
#        'when?'], dtype=object)

# %%
#Create Dataset for each cluster - x24
data = output_samp['text'].values
data_0 = output_samp[output_samp['Topic'] == 0]['text'].values # POLITICS
data_1 = output_samp[output_samp['Topic'] == 1]['text'].values
data_2 = output_samp[output_samp['Topic'] == 2]['text'].values # Swearing
data_3 = output_samp[output_samp['Topic'] == 3]['text'].values # Generic Sports
data_4 = output_samp[output_samp['Topic'] == 4]['text'].values
data_5 = output_samp[output_samp['Topic'] == 5]['text'].values
data_6 = output_samp[output_samp['Topic'] == 6]['text'].values
data_7 = output_samp[output_samp['Topic'] == 7]['text'].values
data_8 = output_samp[output_samp['Topic'] == 8]['text'].values
data_9 = output_samp[output_samp['Topic'] == 9]['text'].values
data_10 = output_samp[output_samp['Topic'] == 10]['text'].values
data_11 = output_samp[output_samp['Topic'] == 11]['text'].values
data_12 = output_samp[output_samp['Topic'] == 12]['text'].values
data_13 = output_samp[output_samp['Topic'] == 13]['text'].values
data_14 = output_samp[output_samp['Topic'] == 14]['text'].values
data_15 = output_samp[output_samp['Topic'] == 15]['text'].values
data_16 = output_samp[output_samp['Topic'] == 16]['text'].values
data_17 = output_samp[output_samp['Topic'] == 17]['text'].values
data_18 = output_samp[output_samp['Topic'] == 18]['text'].values
data_19 = output_samp[output_samp['Topic'] == 19]['text'].values # > (+URLS)
data_20 = output_samp[output_samp['Topic'] == 20]['text'].values
data_21 = output_samp[output_samp['Topic'] == 21]['text'].values
data_22 = output_samp[output_samp['Topic'] == 22]['text'].values
data_23 = output_samp[output_samp['Topic'] == 23]['text'].values
data_24 = output_samp[output_samp['Topic'] == 24]['text'].values
np.set_printoptions(threshold=np.inf)

# %%
#Prepare yearweek counter
splits = df['date'].str.split("/", expand = True)

df['day'] = splits[0].astype(int)
df['month'] = splits[1].astype(int)
df['year'] = splits[2].astype(int)

df['week'] = df.apply(lambda x:return_calander_wk(x.year, x.month, x.day), axis=1)
df['week'] = df['week'].apply(lambda x:extend_weeks(x))

df['text'] = df['text'].astype(str)

# %%
#Aggregate words per yearweek
#df_agg = df.groupby(['yearweek'])['text'].apply(''.join).reset_index()

#Prepare stemming objects
ps = PorterStemmer()

# Load English tokenizer, tagger, parser, NER and word vectors
nlp = English()

df['words'] = df['text'].apply(lambda x: text_cleaning(x))
df['words'] = df['words'].apply(lambda x: tokeniser(x))
df['words'] = df['words'].apply(lambda x: remove_stop_words(x))
#df_agg['words'] = df_agg['words'].apply(lambda x: remove_common_words(x,common_words))
#df['words'] = df['words'].apply(lambda x: stemmer(x))

#df_agg['word_count_dict'] = df_agg['words'].apply(lambda x: CountFrequency(x))

#Word Cloud specific prep
df = df.drop(df[df['text'] == ' MediaShared'].index)
df = df.drop(df[df['text'] == ' DeletedMsg'].index)
df = df.drop(df[df['text'] == ' Deleted Message'].index)

data_words = list(df['words'])

# %%
# Define functions for stopwords, bigrams, trigrams and lemmatization
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out
